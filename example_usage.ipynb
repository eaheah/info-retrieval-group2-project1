# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Imports

# %%
from web_crawler import WebCrawler
from content_processor import ContentProcessor
from analyze import Analyze
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # WebCrawler
#  - WebCrawler can be instantiated with a csv containing seed, num_pages and domain or with keyword arguments
#  - Each WebCrawler instance will immediately begin crawling and upon completion will ouput a list of urls and metadata
#      - Be aware that subsequent instantiations of WebCrawler override the data in the repository folder

# %%
apple_crawler = WebCrawler('specification.csv')
wiki_crawler = WebCrawler(seed='https://en.wikipedia.org/wiki/Main_Page', num_pages=5, domain='en.wikipedia.org')
# Out:
# <table><tr><td>Live URL</td><td>File</td><td>Status</td><td># Links</td><td># Images</td></tr><tr><td><a href=http://www.apple.com/mac>http://www.apple.com/mac<td><a href=repository/1.html>http://www.apple.com/mac/</a></td><td>200</td><td>164</td><td>0</td></tr><tr><td><a href=http://www.apple.com/newsroom>http://www.apple.com/newsroom<td><a href=repository/2.html>http://www.apple.com/newsroom/</a></td><td>200</td><td>105</td><td>0</td></tr><tr><td><a href=http://www.apple.com/homepod>http://www.apple.com/homepod<td><a href=repository/3.html>http://www.apple.com/homepod/</a></td><td>200</td><td>98</td><td>0</td></tr><tr><td><a href=http://www.apple.com/numbers>http://www.apple.com/numbers<td><a href=repository/4.html>http://www.apple.com/numbers/</a></td><td>200</td><td>88</td><td>0</td></tr><tr><td><a href=http://www.apple.com/mac/garageband>http://www.apple.com/mac/garageband<td><a href=repository/5.html>http://www.apple.com/mac/garageband/</a></td><td>200</td><td>114</td><td>0</td></tr></table>
# <table><tr><td>Live URL</td><td>File</td><td>Status</td><td># Links</td><td># Images</td></tr><tr><td><a href=https://en.wikipedia.org/wiki/Main_Page>https://en.wikipedia.org/wiki/Main_Page<td><a href=repository/1.html>https://en.wikipedia.org/wiki/Main_Page</a></td><td>200</td><td>319</td><td>20</td></tr><tr><td><a href=https://en.wikipedia.org/wiki/Indian_Peace_Keeping_Force>https://en.wikipedia.org/wiki/Indian_Peace_Keeping_Force<td><a href=repository/2.html>https://en.wikipedia.org/wiki/Indian_Peace_Keeping_Force</a></td><td>200</td><td>1010</td><td>22</td></tr><tr><td><a href=https://en.wikipedia.org/wiki/Peerage>https://en.wikipedia.org/wiki/Peerage<td><a href=repository/3.html>https://en.wikipedia.org/wiki/Peerage</a></td><td>200</td><td>108</td><td>4</td></tr><tr><td><a href=https://en.wikipedia.org/wiki/Britannia>https://en.wikipedia.org/wiki/Britannia<td><a href=repository/4.html>https://en.wikipedia.org/wiki/Britannia</a></td><td>200</td><td>673</td><td>18</td></tr><tr><td><a href=https://en.wikipedia.org/wiki/October_12>https://en.wikipedia.org/wiki/October_12<td><a href=repository/5.html>https://en.wikipedia.org/wiki/October_12</a></td><td>200</td><td>1491</td><td>7</td></tr></table>

# %% [markdown]
# # Content Processor
#  - TODO

# %%
cp = ContentProcessor()
cp.process_repository()

# %% [markdown]
# # Analysis
#   - An Analyze instance will analyze the text data in the processed folder
#   - the plot_graph method will plot the Zipf's Law for the data
#   - the plot_most_frequent method will plot a table for the first 100 most common words

# %%
analysis = Analyze()
print(f'N = {analysis.total_words}')
# Out:
# N = 34313

# %%
analysis.plot_graph('Relativity')

# %%
analysis.plot_most_frequent()
